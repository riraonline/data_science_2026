# %% [markdown]
# <a href="https://colab.research.google.com/github/riraonline/data_science_2026/blob/main/Pertemuan1_Richardin_Rafsanjani_220401010116.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Sel 1: Output Sederhana
print("Hello Data Science")
# Out:
# Hello Data Science

# %%
#Sel 2: Variabel dan Tipe Data
nama = "Richardin Rafsanjani"
angkatan = 2026
print(f"Halo, nama saya {nama} angkatan {angkatan}")
# Out:
# Halo, nama saya Richardin Rafsanjani angkatan 2026

# %%
#Sel 3: List dan Perulangan
tools = ["Python", "Jupyter", "Numpy", "Colab", "Github"]
for index, item in enumerate(tools, start=1):
    print(f"{index}. {item}")
# Out:
# 1. Python
# 2. Jupyter
# 3. Numpy
# 4. Colab
# 5. Github

# %%
#Sel 4: Fungsi
def perkenalan(nama, prodi, angkatan):
  return f"{nama} | {prodi} | {angkatan}"
output = perkenalan("Richard", "Informatika", 2026)
print(output)
# Out:
# Richard | Informatika | 2026
